# %% [markdown]
# ### **MODELING**

# %% [markdown]
# Since we've been able to properly segment different properties of documents. The next part is to build the model that will be responsible for recognising individual characters.
# **Deep Learning** will be used to classify the images into 75 different groups based on their diacritics.
# The classes for this model are quite much, so we are further going to make try implementing **multi-label classification** and then compare results.
#
# Since our total dataset contains just 41 samples for each class. This might be a negative pull down for deep learning models since they are always data hungry.
#
# **Training data** = 38 samples for each class(**Total = *2850**)
#
# **Testing data** = 3 samples for each class(**Total = 2850**)

# %%
from fastai.vision import *
from fastai.metrics import error_rate, accuracy
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### **LABELS**

# %% [markdown]
# In this dataset, different numbers were used to represent different classes. The image below shows this information

# %%
from IPython.display import Image
Image("/home/max/Pictures/labels.png")

# %%
path = Path('/home/max/Pictures/data')

# %%
data = ImageDataBunch.from_folder(path, train='train', ds_tfms=get_transforms(do_flip = False), valid='test', size=28, bs=64).normalize(imagenet_stats)

# %%
path.ls()
# Out:
# [PosixPath('/home/max/Pictures/data/models'),
#  PosixPath('/home/max/Pictures/data/train'),
#  PosixPath('/home/max/Pictures/data/test')]

# %% [markdown]
# **MODEL ARCHITECTURE (RESNET34)**

# %%
learn = cnn_learner(data, models.resnet34, metrics = [accuracy, error_rate], wd = 1e-1)

# %%
#We unfreeze the pretrained weights of resnet34 from Imagenet and train from scratch
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='3', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [2/3 13:47<06:53]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.991776</td>
#       <td>#na#</td>
#       <td>07:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>12.597283</td>
#       <td>#na#</td>
#       <td>06:20</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='45', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       2.22% [1/45 00:09<06:49 17.9265]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(25, max_lr=slice(1e-04,1e-02))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.018672</td>
#       <td>3.267156</td>
#       <td>0.245614</td>
#       <td>0.754386</td>
#       <td>05:18</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.598524</td>
#       <td>1.898101</td>
#       <td>0.552632</td>
#       <td>0.447368</td>
#       <td>05:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.513129</td>
#       <td>1.295068</td>
#       <td>0.631579</td>
#       <td>0.368421</td>
#       <td>05:03</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.818511</td>
#       <td>1.322428</td>
#       <td>0.719298</td>
#       <td>0.280702</td>
#       <td>04:49</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.423372</td>
#       <td>0.811131</td>
#       <td>0.785088</td>
#       <td>0.214912</td>
#       <td>05:02</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.317144</td>
#       <td>1.012913</td>
#       <td>0.754386</td>
#       <td>0.245614</td>
#       <td>04:51</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.185955</td>
#       <td>0.755856</td>
#       <td>0.793860</td>
#       <td>0.206140</td>
#       <td>04:55</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.066794</td>
#       <td>0.531541</td>
#       <td>0.859649</td>
#       <td>0.140351</td>
#       <td>04:39</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.858294</td>
#       <td>0.484366</td>
#       <td>0.846491</td>
#       <td>0.153509</td>
#       <td>05:04</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.744537</td>
#       <td>0.680067</td>
#       <td>0.828947</td>
#       <td>0.171053</td>
#       <td>04:52</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.655711</td>
#       <td>0.413058</td>
#       <td>0.855263</td>
#       <td>0.144737</td>
#       <td>04:57</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.570817</td>
#       <td>0.359935</td>
#       <td>0.890351</td>
#       <td>0.109649</td>
#       <td>05:13</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.531634</td>
#       <td>0.411631</td>
#       <td>0.881579</td>
#       <td>0.118421</td>
#       <td>05:07</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.495601</td>
#       <td>0.355642</td>
#       <td>0.894737</td>
#       <td>0.105263</td>
#       <td>05:18</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.443785</td>
#       <td>0.289459</td>
#       <td>0.907895</td>
#       <td>0.092105</td>
#       <td>05:35</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.412372</td>
#       <td>0.304634</td>
#       <td>0.907895</td>
#       <td>0.092105</td>
#       <td>05:08</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.347428</td>
#       <td>0.238899</td>
#       <td>0.934211</td>
#       <td>0.065789</td>
#       <td>04:37</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.301890</td>
#       <td>0.255166</td>
#       <td>0.921053</td>
#       <td>0.078947</td>
#       <td>05:10</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.267730</td>
#       <td>0.271112</td>
#       <td>0.907895</td>
#       <td>0.092105</td>
#       <td>05:22</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.226334</td>
#       <td>0.184799</td>
#       <td>0.947368</td>
#       <td>0.052632</td>
#       <td>04:57</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.191801</td>
#       <td>0.146421</td>
#       <td>0.964912</td>
#       <td>0.035088</td>
#       <td>05:26</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.159454</td>
#       <td>0.177632</td>
#       <td>0.956140</td>
#       <td>0.043860</td>
#       <td>05:20</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.144392</td>
#       <td>0.195923</td>
#       <td>0.929825</td>
#       <td>0.070175</td>
#       <td>05:13</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.130107</td>
#       <td>0.182866</td>
#       <td>0.947368</td>
#       <td>0.052632</td>
#       <td>05:12</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.119803</td>
#       <td>0.193324</td>
#       <td>0.942982</td>
#       <td>0.057018</td>
#       <td>04:54</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('model1')

# %% [markdown]
# From our test set of **228** images, we can see that we were able to grab a very good accuracy of up to **93.42%**. This is quite good and reasonable for this model

# %% [markdown]
# **LOSS PLOT:** In this model we can see how our model increased efficiently

# %%
learn.recorder.plot_losses()

# %% [markdown]
# The plot below also shows how the **accuracy** increased over batches as well as how the **error rate** properly reduced.

# %%
learn.recorder.plot_metrics()

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %% [markdown]
# The images below shows images that were wrongly classified
#
# **Format - correct/prediction/...**

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %% [markdown]
# #### **CONFUSION MATRIX**
#
# This plot below shows the confusion matrix descibing the particular classes which our models are **good/bad** at.
#
# **From this plot we can draw a conclusion that most our mistake were differentiating some capital letters from small letters. This is not too bad in real world scenario since it won't produce a wromd spelling**

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)
